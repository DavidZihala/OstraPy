# %% [markdown]
# **1. Prepare scatter plot with given data (x,y). Try to use both approaches (stateful, stateles). Your graph should include title, xlabel, ylabel and grid. Save your graph as my_plot.pdf.**

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5,7,8,9,10,11]
y = [1,3,5,8,1,6,3,6,8,9]

# %%
#stateful approach
plt.scatter(x,y)
plt.title('Some title...')
plt.xlabel('xlabel')
plt.ylabel('ylabel')
plt.grid()
plt.savefig('my_plot.pdf')

# %%
#stateles approach
fig, ax = plt.subplots()
ax.scatter(x,y)
ax.set_title('Some title...')
ax.set_xlabel('xlabel')
ax.set_ylabel('ylabel')
ax.grid()
plt.savefig('my_plot.pdf')

# %% [markdown]
# **2. Try to make same graph as in ex2.pdf with given data (x1,y1,x2,y2)**

# %%
x1 = [1,2,3,4,5,7,8,9,10,11]
y1 = [1,3,5,8,1,6,3,6,8,9]
x2a = [1, 0, 2, 4, 6]
x2b = [1, 2, 3, 3, 4]

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
ax1.scatter(x,y)
ax1.set_title('Some title...')
ax1.set_xlabel('xlabel')
ax1.set_ylabel('ylabel')
ax1.grid()


ax2.plot(x2a, label='I am boring', color='blue', linestyle='dashed')
ax2.plot(x2b, label="legend", color='red')
ax2.set_xlabel('This is the X axis')
ax2.set_ylabel('This is the Y axis')
ax2.set_title('I am title!')
ax2.legend()
ax2.set_xticks([1, 2, 3, 4, 5])

plt.savefig('ex2.pdf')
